# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
fifa= pd.read_csv("players19.csv")

# %%
fifa.head()
# Out:
#    sofifa_id                                         player_url  \
# 0      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 1     158023  https://sofifa.com/player/158023/lionel-messi/...
# 2     190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3     193080  https://sofifa.com/player/193080/david-de-gea-...
# 4     192985  https://sofifa.com/player/192985/kevin-de-bruy...
#
#           short_name                            long_name  age         dob  \
# 0  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   33  1985-02-05
# 1           L. Messi       Lionel Andrés Messi Cuccittini   31  1987-06-24
# 2          Neymar Jr        Neymar da Silva Santos Junior   26  1992-02-05
# 3             De Gea                David De Gea Quintana   27  1990-11-07
# 4       K. De Bruyne                      Kevin De Bruyne   27  1991-06-28
#
#    height_cm  weight_kg nationality                 club  ...   lwb   ldm  \
# ...

# %%
for col in fifa.columns:
    print(col)
# Out:
# sofifa_id
# player_url
# short_name
# long_name
# age
# dob
# height_cm
# weight_kg
# nationality
# club
# overall
# potential
# value_eur
# wage_eur
# player_positions
# preferred_foot
# international_reputation
# weak_foot
# skill_moves
# work_rate
# body_type
# real_face
# release_clause_eur
# player_tags
# team_position
# team_jersey_number
# loaned_from
# joined
# contract_valid_until
# nation_position
# nation_jersey_number
# pace
# shooting
# passing
# dribbling
# defending
# physic
# gk_diving
# gk_handling
# gk_kicking
# gk_reflexes
# gk_speed
# gk_positioning
# player_traits
# attacking_crossing
# attacking_finishing
# attacking_heading_accuracy
# attacking_short_passing
# attacking_volleys
# skill_dribbling
# skill_curve
# skill_fk_accuracy
# skill_long_passing
# skill_ball_control
# movement_acceleration
# movement_sprint_speed
# movement_agility
# movement_reactions
# movement_balance
# power_shot_power
# power_jumping
# power_stamina
# power_strength
# power_long_shots
# ...

# %%
fifa.shape
# Out:
# (17770, 104)

# %%
17770*104
# Out:
# 1848080

# %%
fifa['nationality'].value_counts()
# Out:
# England                 1656
# Germany                 1191
# Spain                   1037
# Argentina                943
# France                   892
#                         ...
# New Caledonia              1
# Mauritius                  1
# United Arab Emirates       1
# Guam                       1
# Indonesia                  1
# Name: nationality, Length: 160, dtype: int64

# %%
fifa['nationality'].value_counts()[0:10]
# Out:
# England        1656
# Germany        1191
# Spain          1037
# Argentina       943
# France          892
# Brazil          816
# Italy           744
# Colombia        588
# Japan           455
# Netherlands     418
# Name: nationality, dtype: int64

# %%
fifa['nationality'].value_counts()[0:5].keys()
# Out:
# Index(['England', 'Germany', 'Spain', 'Argentina', 'France'], dtype='object')

# %%
fifa['nationality'].value_counts()[0:5]
# Out:
# England      1656
# Germany      1191
# Spain        1037
# Argentina     943
# France        892
# Name: nationality, dtype: int64

# %%
fifa['nationality'].value_counts()[0:5]
# Out:
# England      1656
# Germany      1191
# Spain        1037
# Argentina     943
# France        892
# Name: nationality, dtype: int64

# %%
plt.figure(figsize=(5,5))
plt.bar(list(fifa['nationality'].value_counts()[0:5].keys()),list(fifa['nationality'].value_counts()[0:5]),color="r")
plt.show()

# %%
player_salary= fifa[['short_name','wage_eur']]

# %%
player_salary.head()
# Out:
#           short_name  wage_eur
# 0  Cristiano Ronaldo    405000
# 1           L. Messi    565000
# 2          Neymar Jr    290000
# 3             De Gea    260000
# 4       K. De Bruyne    355000

# %%
player_salary= player_salary.sort_values(by=['wage_eur'], ascending= False)

# %%
player_salary.head()
# Out:
#           short_name  wage_eur
# 1           L. Messi    565000
# 6          L. Suárez    455000
# 7          L. Modrić    420000
# 0  Cristiano Ronaldo    405000
# 5       Sergio Ramos    380000

# %%
plt.figure(figsize=(7,5))
plt.bar(list(player_salary['short_name'])[0:5], list(player_salary['wage_eur'])[0:5], color=["red", "green", "blue", "pink", "black"])
plt.show()

# %%
fifa['nationality']=='Spain'
# Out:
# 0        False
# 1        False
# 2        False
# 3         True
# 4        False
#          ...
# 17765    False
# 17766    False
# 17767    False
# 17768    False
# 17769    False
# Name: nationality, Length: 17770, dtype: bool

# %%
#Spain
Spain=fifa[fifa['nationality']=='Spain']
Spain.head(10)
# Out:
#     sofifa_id                                         player_url  \
# 3      193080  https://sofifa.com/player/193080/david-de-gea-...
# 5      155862  https://sofifa.com/player/155862/sergio-ramos-...
# 17     197781  https://sofifa.com/player/197781/francisco-rom...
# 23     168542  https://sofifa.com/player/168542/david-josue-j...
# 39     189511  https://sofifa.com/player/189511/sergio-busque...
# 46     152729  https://sofifa.com/player/152729/gerard-pique-...
# 53     189332  https://sofifa.com/player/189332/jordi-alba-ra...
# 61     184432  https://sofifa.com/player/184432/cesar-azpilic...
# 71     189509  https://sofifa.com/player/189509/thiago-alcant...
# 72     189513  https://sofifa.com/player/189513/daniel-parejo...
#
#          short_name                       long_name  age         dob  \
# 3            De Gea           David De Gea Quintana   27  1990-11-07
# 5      Sergio Ramos             Sergio Ramos García   32  1986-03-30
# ...

# %%
#Spain
Spain.sort_values(by=['height_cm'], ascending= False).head()
# Out:
#        sofifa_id                                         player_url  \
# 15117     231187  https://sofifa.com/player/231187/hodei-oleaga-...
# 14388     228789  https://sofifa.com/player/228789/robert-lynch-...
# 486       146748  https://sofifa.com/player/146748/diego-lopez-r...
# 2455      186680  https://sofifa.com/player/186680/raul-fdez-cav...
# 2003      189709  https://sofifa.com/player/189709/pedro-alcala-...
#
#            short_name                     long_name  age         dob  \
# 15117          Oleaga          Hodei Oleaga Alarcia   21  1996-12-29
# 14388  Robert Sanchez          Robert Lynch Sanchez   20  1997-11-18
# 486       Diego López         Diego López Rodríguez   36  1981-11-03
# 2455   Raúl Fernández  Raúl Fernández-Cavada Mateos   30  1988-03-13
# 2003           Alcalá          Pedro Alcalá Guirado   29  1989-03-19
#
#        height_cm  weight_kg nationality                     club  ...   lwb  \
# ...

# %%
#Spain
Spain.sort_values(by=['weight_kg'], ascending= False).head()
# Out:
#       sofifa_id                                         player_url short_name  \
# 3074     191688  https://sofifa.com/player/191688/alberto-tomas...      Botía
# 913      193152  https://sofifa.com/player/193152/iago-herrerin...   Herrerín
# 2003     189709  https://sofifa.com/player/189709/pedro-alcala-...     Alcalá
# 1160     183666  https://sofifa.com/player/183666/roberto-jimen...    Roberto
# 1113     162131  https://sofifa.com/player/162131/fernando-javi...   Llorente
#
#                             long_name  age         dob  height_cm  weight_kg  \
# 3074      Alberto Tomás Botía Rabasco   29  1989-01-27        189         96
# 913              Iago Herrerín Buisán   30  1988-01-25        187         95
# 2003             Pedro Alcalá Guirado   29  1989-03-19        196         93
# 1160             Roberto Jiménez Gago   32  1986-02-10        192         93
# 1113  Fernando Javier Llorente Torres   33  1985-02-26        193         92
#
# ...

# %%
#Spain
Spain.sort_values(by=['wage_eur'], ascending= False).head()
# Out:
#     sofifa_id                                         player_url  \
# 5      155862  https://sofifa.com/player/155862/sergio-ramos-...
# 17     197781  https://sofifa.com/player/197781/francisco-rom...
# 39     189511  https://sofifa.com/player/189511/sergio-busque...
# 23     168542  https://sofifa.com/player/168542/david-josue-j...
# 3      193080  https://sofifa.com/player/193080/david-de-gea-...
#
#          short_name                       long_name  age         dob  \
# 5      Sergio Ramos             Sergio Ramos García   32  1986-03-30
# 17             Isco  Francisco Román Alarcón Suárez   26  1992-04-21
# 39  Sergio Busquets        Sergio Busquets i Burgos   29  1988-07-16
# 23      David Silva       David Josué Jiménez Silva   32  1986-01-08
# 3            De Gea           David De Gea Quintana   27  1990-11-07
#
#     height_cm  weight_kg nationality               club  ...   lwb   ldm  \
# 5         184         82       Spain        Real Madrid  ...  82+3  83+3
# ...

# %%
#Spain
Spain[['short_name', 'wage_eur']].sort_values(by=['wage_eur'], ascending= False).head(6)
# Out:
#          short_name  wage_eur
# 5      Sergio Ramos    380000
# 17             Isco    325000
# 39  Sergio Busquets    300000
# 23      David Silva    275000
# 3            De Gea    260000
# 53       Jordi Alba    250000

# %%
#Players with best Passing

player_passing= fifa[['short_name', 'club', 'nationality', 'passing']]

# %%
player_passing.sort_values(by=['passing'], ascending=False).head()
# Out:
#       short_name               club nationality  passing
# 4   K. De Bruyne    Manchester City     Belgium     92.0
# 7      L. Modrić        Real Madrid     Croatia     90.0
# 13      T. Kroos        Real Madrid     Germany     89.0
# 26    C. Eriksen  Tottenham Hotspur     Denmark     89.0
# 1       L. Messi       FC Barcelona   Argentina     88.0

# %%
#Work Rate

player_workrate= fifa[['short_name', 'age', 'defending', 'height_cm', 'club']]

# %%
player_workrate.sort_values(by=['defending'], ascending=False).head()
# Out:
#        short_name  age  defending  height_cm               club
# 5    Sergio Ramos   32       91.0        184        Real Madrid
# 21   G. Chiellini   33       91.0        187           Juventus
# 24     M. Hummels   29       90.0        191  FC Bayern München
# 135   A. Barzagli   37       89.0        187           Juventus
# 12       D. Godín   32       89.0        187    Atlético Madrid

# %%
liverpool= fifa[fifa['club']== 'Liverpool']

# %%
#Salary
liverpool.sort_values(by= ['wage_eur'], ascending= False).head()
# Out:
#     sofifa_id                                         player_url  \
# 31     209331  https://sofifa.com/player/209331/mohamed-salah...
# 60     201942  https://sofifa.com/player/201942/roberto-firmi...
# 62     208722  https://sofifa.com/player/208722/sadio-mane/19...
# 89     203376  https://sofifa.com/player/203376/virgil-van-di...
# 83     209499  https://sofifa.com/player/209499/fabio-henriqu...
#
#          short_name                            long_name  age         dob  \
# 31         M. Salah                 Mohamed  Salah Ghaly   26  1992-06-15
# 60  Roberto Firmino  Roberto Firmino Barbosa de Oliveira   26  1991-10-02
# 62          S. Mané                           Sadio Mané   26  1992-04-10
# 89      V. van Dijk                      Virgil van Dijk   26  1991-07-08
# 83          Fabinho               Fábio Henrique Tavares   24  1993-10-23
#
#     height_cm  weight_kg  nationality       club  ...   lwb   ldm   cdm   rdm  \
# ...

# %%
#Shooting
liverpool.sort_values(by= ['shooting'], ascending= False).head()
# Out:
#      sofifa_id                                         player_url  \
# 31      209331  https://sofifa.com/player/209331/mohamed-salah...
# 60      201942  https://sofifa.com/player/201942/roberto-firmi...
# 503     171833  https://sofifa.com/player/171833/daniel-sturri...
# 62      208722  https://sofifa.com/player/208722/sadio-mane/19...
# 354     193348  https://sofifa.com/player/193348/xherdan-shaqi...
#
#           short_name                            long_name  age         dob  \
# 31          M. Salah                 Mohamed  Salah Ghaly   26  1992-06-15
# 60   Roberto Firmino  Roberto Firmino Barbosa de Oliveira   26  1991-10-02
# 503     D. Sturridge               Daniel Andre Sturridge   28  1989-09-01
# 62           S. Mané                           Sadio Mané   26  1992-04-10
# 354       X. Shaqiri                      Xherdan Shaqiri   26  1991-10-10
#
#      height_cm  weight_kg  nationality       club  ...   lwb   ldm   cdm  \
# ...

# %%
#Defending
liverpool.sort_values(by= ['defending'], ascending= False).head()
# Out:
#      sofifa_id                                         player_url  \
# 89      203376  https://sofifa.com/player/203376/virgil-van-di...
# 83      209499  https://sofifa.com/player/209499/fabio-henriqu...
# 348     197061  https://sofifa.com/player/197061/joel-matip/19...
# 355     195086  https://sofifa.com/player/195086/dejan-lovren/...
# 460     190456  https://sofifa.com/player/190456/nathaniel-cly...
#
#       short_name               long_name  age         dob  height_cm  \
# 89   V. van Dijk         Virgil van Dijk   26  1991-07-08        193
# 83       Fabinho  Fábio Henrique Tavares   24  1993-10-23        188
# 348     J. Matip    Joël Andre Job Matip   26  1991-08-08        195
# 355    D. Lovren            Dejan Lovren   28  1989-07-05        188
# 460     N. Clyne   Nathaniel Edwin Clyne   27  1991-04-05        175
#
#      weight_kg  nationality       club  ...   lwb   ldm   cdm   rdm   rwb  \
# 89          92  Netherlands  Liverpool  ...  75+3  80+3  80+3  80+3  75+3
# ...

# %%
liverpool['nationality'].value_counts()
# Out:
# England                13
# Brazil                  3
# Netherlands             3
# Belgium                 2
# Spain                   2
# Egypt                   1
# Senegal                 1
# Guinea                  1
# Scotland                1
# Cameroon                1
# Switzerland             1
# Croatia                 1
# Serbia                  1
# Portugal                1
# Republic of Ireland     1
# Name: nationality, dtype: int64
